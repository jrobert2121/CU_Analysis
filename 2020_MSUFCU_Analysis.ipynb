# %%
import pandas as pd

# %%
#import 2020 Q1 files
foicu_df = pd.read_csv('2020_Q1/FOICU.txt', sep = ',')
fs220_df = pd.read_csv("2020_Q1/FS220.txt", sep = ',')
fs220a_df = pd.read_csv('2020_Q1/FS220A.txt', sep = ',')
fs220b_df = pd.read_csv('2020_Q1/FS220B.txt', sep = ',')
fs220d_df = pd.read_csv('2020_Q1/FS220D.txt', sep = ',')
fs220g_df = pd.read_csv('2020_Q1/FS220G.txt', sep = ',')
fs220l_df = pd.read_csv('2020_Q1/FS220L.txt', sep = ',')
fs220m_df = pd.read_csv('2020_Q1/FS220M.txt', sep = ',')

# %%
# create Q1_2020_df
Q1_2020_data = [foicu_df['CU_NUMBER'], foicu_df['CYCLE_DATE'], foicu_df['CU_NAME'], foicu_df['STATE'],
        fs220_df['ACCT_010'], fs220_df['ACCT_083'], fs220d_df['Acct_700'], fs220a_df['Acct_998'], fs220_df['ACCT_523'],
               fs220b_df['ACCT_958'], fs220a_df['ACCT_385'], fs220_df['ACCT_524'], fs220_df['ACCT_968'], fs220a_df['ACCT_370'],
               fs220a_df['ACCT_565'], fs220a_df['Acct_954'], fs220a_df['ACCT_002'], fs220l_df['ACCT_595B'],
               fs220m_df['ACCT_963C'], fs220l_df['ACCT_698C'], fs220_df['ACCT_521'], fs220b_df['ACCT_993'],
               fs220a_df['ACCT_396'], fs220_df['ACCT_522'], fs220b_df['ACCT_994'], fs220a_df['ACCT_397'],
               fs220l_df['ACCT_563A'], fs220m_df['ACCT_959A'], fs220l_df['ACCT_703A'], fs220l_df['ACCT_562A'],
               fs220m_df['ACCT_960A'], fs220l_df['ACCT_386A']]

# create headers
Q1_2020_headers = ['CU_Number', 'Cycle_Date', 'CU_Name', 'State', 'Total_Assets', 'Current_mbrs',
          'Classification', 'Net_worth_ratio', 'New_Auto_Rate', '#New_Auto', '$New_Auto', 'Used_Auto_Rate', '#Used_Auto',
                  '$Used_Auto', 'Lease_Rate', '#Lease', '$Lease', 'Other_Secured_Rate', '#Other_Secured', '$Other_Secured',
                  'CC_Rate', '#CC', '$CC', 'Other_Unsecured_Rate', '#Other_Unsecured', '$Other_Unsecured',
                  '1st_Mtg_Rate', '#1st_Mtg', '$1st_Mtg', '2nd_Mtg_Rate', '#2nd_Mtg', '$2nd_Mtg']

Q1_2020_df = pd.concat(Q1_2020_data, axis=1, keys=Q1_2020_headers)

# %%
#import 2020 Q2 files
foicu_df = pd.read_csv('2020_Q2/FOICU.txt', sep = ',')
fs220_df = pd.read_csv("2020_Q2/FS220.txt", sep = ',')
fs220a_df = pd.read_csv('2020_Q2/FS220A.txt', sep = ',')
fs220b_df = pd.read_csv('2020_Q2/FS220B.txt', sep = ',')
fs220d_df = pd.read_csv('2020_Q2/FS220D.txt', sep = ',')
fs220g_df = pd.read_csv('2020_Q2/FS220G.txt', sep = ',')
fs220l_df = pd.read_csv('2020_Q2/FS220L.txt', sep = ',')
fs220m_df = pd.read_csv('2020_Q2/FS220M.txt', sep = ',')

# %%
# create Q2_2020_df
Q2_2020_data = [foicu_df['CU_NUMBER'], foicu_df['CYCLE_DATE'], foicu_df['CU_NAME'], foicu_df['STATE'],
        fs220_df['ACCT_010'], fs220_df['ACCT_083'], fs220d_df['Acct_700'], fs220a_df['Acct_998'], fs220_df['ACCT_523'],
               fs220b_df['ACCT_958'], fs220a_df['ACCT_385'], fs220_df['ACCT_524'], fs220_df['ACCT_968'], fs220a_df['ACCT_370'],
               fs220a_df['ACCT_565'], fs220a_df['Acct_954'], fs220a_df['ACCT_002'], fs220l_df['ACCT_595B'],
               fs220m_df['ACCT_963C'], fs220l_df['ACCT_698C'], fs220_df['ACCT_521'], fs220b_df['ACCT_993'],
               fs220a_df['ACCT_396'], fs220_df['ACCT_522'], fs220b_df['ACCT_994'], fs220a_df['ACCT_397'],
               fs220l_df['ACCT_563A'], fs220m_df['ACCT_959A'], fs220l_df['ACCT_703A'], fs220l_df['ACCT_562A'],
               fs220m_df['ACCT_960A'], fs220l_df['ACCT_386A']]

# create headers
Q2_2020_headers = ['CU_Number', 'Cycle_Date', 'CU_Name', 'State', 'Total_Assets', 'Current_mbrs',
          'Classification', 'Net_worth_ratio', 'New_Auto_Rate', '#New_Auto', '$New_Auto', 'Used_Auto_Rate', '#Used_Auto',
                  '$Used_Auto', 'Lease_Rate', '#Lease', '$Lease', 'Other_Secured_Rate', '#Other_Secured', '$Other_Secured',
                  'CC_Rate', '#CC', '$CC', 'Other_Unsecured_Rate', '#Other_Unsecured', '$Other_Unsecured',
                  '1st_Mtg_Rate', '#1st_Mtg', '$1st_Mtg', '2nd_Mtg_Rate', '#2nd_Mtg', '$2nd_Mtg']

Q2_2020_df = pd.concat(Q2_2020_data, axis=1, keys=Q2_2020_headers)

# %%
#import 2020 Q3 files
foicu_df = pd.read_csv('2020_Q3/FOICU.txt', sep = ',')
fs220_df = pd.read_csv("2020_Q3/FS220.txt", sep = ',')
fs220a_df = pd.read_csv('2020_Q3/FS220A.txt', sep = ',')
fs220b_df = pd.read_csv('2020_Q3/FS220B.txt', sep = ',')
fs220d_df = pd.read_csv('2020_Q3/FS220D.txt', sep = ',')
fs220g_df = pd.read_csv('2020_Q3/FS220G.txt', sep = ',')
fs220l_df = pd.read_csv('2020_Q3/FS220L.txt', sep = ',')
fs220m_df = pd.read_csv('2020_Q3/FS220M.txt', sep = ',')

# %%
# create Q3_2020_df
Q3_2020_data = [foicu_df['CU_NUMBER'], foicu_df['CYCLE_DATE'], foicu_df['CU_NAME'], foicu_df['STATE'],
        fs220_df['ACCT_010'], fs220_df['ACCT_083'], fs220d_df['Acct_700'], fs220a_df['Acct_998'], fs220_df['ACCT_523'],
               fs220b_df['ACCT_958'], fs220a_df['ACCT_385'], fs220_df['ACCT_524'], fs220_df['ACCT_968'], fs220a_df['ACCT_370'],
               fs220a_df['ACCT_565'], fs220a_df['Acct_954'], fs220a_df['ACCT_002'], fs220l_df['ACCT_595B'],
               fs220m_df['ACCT_963C'], fs220l_df['ACCT_698C'], fs220_df['ACCT_521'], fs220b_df['ACCT_993'],
               fs220a_df['ACCT_396'], fs220_df['ACCT_522'], fs220b_df['ACCT_994'], fs220a_df['ACCT_397'],
               fs220l_df['ACCT_563A'], fs220m_df['ACCT_959A'], fs220l_df['ACCT_703A'], fs220l_df['ACCT_562A'],
               fs220m_df['ACCT_960A'], fs220l_df['ACCT_386A']]

# create headers
Q3_2020_headers = ['CU_Number', 'Cycle_Date', 'CU_Name', 'State', 'Total_Assets', 'Current_mbrs',
          'Classification', 'Net_worth_ratio', 'New_Auto_Rate', '#New_Auto', '$New_Auto', 'Used_Auto_Rate', '#Used_Auto',
                  '$Used_Auto', 'Lease_Rate', '#Lease', '$Lease', 'Other_Secured_Rate', '#Other_Secured', '$Other_Secured',
                  'CC_Rate', '#CC', '$CC', 'Other_Unsecured_Rate', '#Other_Unsecured', '$Other_Unsecured',
                  '1st_Mtg_Rate', '#1st_Mtg', '$1st_Mtg', '2nd_Mtg_Rate', '#2nd_Mtg', '$2nd_Mtg']

Q3_2020_df = pd.concat(Q3_2020_data, axis=1, keys=Q3_2020_headers)

# %%
#import 2020 Q4 files
foicu_df = pd.read_csv('2020_Q4/FOICU.txt', sep = ',')
fs220_df = pd.read_csv("2020_Q4/FS220.txt", sep = ',')
fs220a_df = pd.read_csv('2020_Q4/FS220A.txt', sep = ',')
fs220b_df = pd.read_csv('2020_Q4/FS220B.txt', sep = ',')
fs220d_df = pd.read_csv('2020_Q4/FS220D.txt', sep = ',')
fs220g_df = pd.read_csv('2020_Q4/FS220G.txt', sep = ',')
fs220l_df = pd.read_csv('2020_Q4/FS220L.txt', sep = ',')
fs220m_df = pd.read_csv('2020_Q4/FS220M.txt', sep = ',')

# %%
# create Q4_2020_df
Q4_2020_data = [foicu_df['CU_NUMBER'], foicu_df['CYCLE_DATE'], foicu_df['CU_NAME'], foicu_df['STATE'],
        fs220_df['ACCT_010'], fs220_df['ACCT_083'], fs220d_df['Acct_700'], fs220a_df['Acct_998'], fs220_df['ACCT_523'],
               fs220b_df['ACCT_958'], fs220a_df['ACCT_385'], fs220_df['ACCT_524'], fs220_df['ACCT_968'], fs220a_df['ACCT_370'],
               fs220a_df['ACCT_565'], fs220a_df['Acct_954'], fs220a_df['ACCT_002'], fs220l_df['ACCT_595B'],
               fs220m_df['ACCT_963C'], fs220l_df['ACCT_698C'], fs220_df['ACCT_521'], fs220b_df['ACCT_993'],
               fs220a_df['ACCT_396'], fs220_df['ACCT_522'], fs220b_df['ACCT_994'], fs220a_df['ACCT_397'],
               fs220l_df['ACCT_563A'], fs220m_df['ACCT_959A'], fs220l_df['ACCT_703A'], fs220l_df['ACCT_562A'],
               fs220m_df['ACCT_960A'], fs220l_df['ACCT_386A']]

# create headers
Q4_2020_headers = ['CU_Number', 'Cycle_Date', 'CU_Name', 'State', 'Total_Assets', 'Current_mbrs',
          'Classification', 'Net_worth_ratio', 'New_Auto_Rate', '#New_Auto', '$New_Auto', 'Used_Auto_Rate', '#Used_Auto',
                  '$Used_Auto', 'Lease_Rate', '#Lease', '$Lease', 'Other_Secured_Rate', '#Other_Secured', '$Other_Secured',
                  'CC_Rate', '#CC', '$CC', 'Other_Unsecured_Rate', '#Other_Unsecured', '$Other_Unsecured',
                  '1st_Mtg_Rate', '#1st_Mtg', '$1st_Mtg', '2nd_Mtg_Rate', '#2nd_Mtg', '$2nd_Mtg']

Q4_2020_df = pd.concat(Q4_2020_data, axis=1, keys=Q4_2020_headers)

# %%
entries = [Q2_2020_df, Q3_2020_df, Q4_2020_df]

# %%
Y2020_df = Q1_2020_df.append(entries)

# %%
Y2020_df.head(20)
# Out:
#     CU_Number         Cycle_Date                            CU_Name State  \
# 0           1  3/31/2020 0:00:00          MORRIS SHEPPARD TEXARKANA    TX
# 1           5  3/31/2020 0:00:00                       FIRST CASTLE    LA
# 2           6  3/31/2020 0:00:00          THE NEW ORLEANS FIREMEN'S    LA
# 3          12  3/31/2020 0:00:00                     FRANKLIN TRUST    CT
# 4          13  3/31/2020 0:00:00                     EFCU FINANCIAL    LA
# 5          16  3/31/2020 0:00:00                            WOODMEN    NE
# 6          19  3/31/2020 0:00:00                 NEW HAVEN TEACHERS    CT
# 7          22  3/31/2020 0:00:00     WATERBURY CONNECTICUT TEACHERS    CT
# 8          26  3/31/2020 0:00:00                            FARMERS    FL
# 9          28  3/31/2020 0:00:00                            CENTRIS    NE
# 10         42  3/31/2020 0:00:00                       FD COMMUNITY    CT
# 11         47  3/31/2020 0:00:00               FARGO PUBLIC SCHOOLS    ND
# ...

# %%
# format Y2020_df
# convert cycle date to datetime
Y2020_df['Cycle_Date'] = pd.to_datetime(Y2020_df['Cycle_Date'])
Y2020_df['Cycle_Date'] = Y2020_df['Cycle_Date'].dt.strftime('%m-%d-%Y')

# Format the columns have the comma for a thousands separator.
Y2020_df["Total_Assets"] = Y2020_df["Total_Assets"].map("${:,}".format)
Y2020_df["Current_mbrs"] = Y2020_df["Current_mbrs"].map("{:,}".format)
Y2020_df["#New_Auto"] = Y2020_df["#New_Auto"].map("{:,}".format)
Y2020_df["$New_Auto"] = Y2020_df["$New_Auto"].map("${:,}".format)
Y2020_df["#Used_Auto"] = Y2020_df["#Used_Auto"].map("{:,}".format)
Y2020_df["$Used_Auto"] = Y2020_df["$Used_Auto"].map("${:,}".format)
Y2020_df["#Lease"] = Y2020_df["#Lease"].map("{:,}".format)
Y2020_df["$Lease"] = Y2020_df["$Lease"].map("${:,}".format)
Y2020_df["#Other_Secured"] = Y2020_df["#Other_Secured"].map("{:,}".format)
Y2020_df["$Other_Secured"] = Y2020_df["$Other_Secured"].map("${:,}".format)
Y2020_df["#CC"] = Y2020_df["#CC"].map("{:,}".format)
Y2020_df["$CC"] = Y2020_df["$CC"].map("${:,}".format)
Y2020_df["#Other_Unsecured"] = Y2020_df["#Other_Unsecured"].map("{:,}".format)
Y2020_df["$Other_Unsecured"] = Y2020_df["$Other_Unsecured"].map("${:,}".format)
Y2020_df["#1st_Mtg"] = Y2020_df["#1st_Mtg"].map("{:,}".format)
Y2020_df["$1st_Mtg"] = Y2020_df["$1st_Mtg"].map("${:,}".format)
Y2020_df["#2nd_Mtg"] = Y2020_df["#2nd_Mtg"].map("{:,}".format)
Y2020_df["$2nd_Mtg"] = Y2020_df["$2nd_Mtg"].map("${:,}".format)

# format net worth ratio
Y2020_df['Net_worth_ratio'] = Y2020_df['Net_worth_ratio'].astype(float)
Y2020_df['Net_worth_ratio'] = Y2020_df['Net_worth_ratio'] / 100

# format rate columns
Y2020_df['New_Auto_Rate'] = Y2020_df['New_Auto_Rate'] / 100
Y2020_df['Used_Auto_Rate'] = Y2020_df['Used_Auto_Rate'] / 100
Y2020_df['Lease_Rate'] = Y2020_df['Lease_Rate'] / 100
Y2020_df['Other_Secured_Rate'] = Y2020_df['Other_Secured_Rate'] / 100
Y2020_df['CC_Rate'] = Y2020_df['CC_Rate'] / 100
Y2020_df['Other_Unsecured_Rate'] = Y2020_df['Other_Unsecured_Rate'] / 100
Y2020_df['1st_Mtg_Rate'] = Y2020_df['1st_Mtg_Rate'] / 100
Y2020_df['2nd_Mtg_Rate'] = Y2020_df['2nd_Mtg_Rate'] / 100

Y2020_df
# Out:
#       CU_Number  Cycle_Date                    CU_Name State  Total_Assets  \
# 0             1  03-31-2020  MORRIS SHEPPARD TEXARKANA    TX    $8,352,746
# 1             5  03-31-2020               FIRST CASTLE    LA   $69,156,077
# 2             6  03-31-2020  THE NEW ORLEANS FIREMEN'S    LA  $181,602,702
# 3            12  03-31-2020             FRANKLIN TRUST    CT   $45,098,321
# 4            13  03-31-2020             EFCU FINANCIAL    LA  $566,660,170
# ...         ...         ...                        ...   ...           ...
# 5202      97107  12-31-2020               UNITED TEXAS    TX  $292,005,173
# 5203      97108  12-31-2020        NORTHWEST COMMUNITY    IL   $57,096,431
# 5204      97109  12-31-2020               RIVER VALLEY    OH  $393,016,300
# 5205      97110  12-31-2020             ROCKY MOUNTAIN    MT  $316,032,867
# 5206      97111  12-31-2020                      ABBEY    OH  $112,006,788
#
# ...

# %%
# change index to CU_Number
Y2020_df.set_index('CU_Number')
# Out:
#            Cycle_Date                    CU_Name State  Total_Assets  \
# CU_Number
# 1          03-31-2020  MORRIS SHEPPARD TEXARKANA    TX    $8,352,746
# 5          03-31-2020               FIRST CASTLE    LA   $69,156,077
# 6          03-31-2020  THE NEW ORLEANS FIREMEN'S    LA  $181,602,702
# 12         03-31-2020             FRANKLIN TRUST    CT   $45,098,321
# 13         03-31-2020             EFCU FINANCIAL    LA  $566,660,170
# ...               ...                        ...   ...           ...
# 97107      12-31-2020               UNITED TEXAS    TX  $292,005,173
# 97108      12-31-2020        NORTHWEST COMMUNITY    IL   $57,096,431
# 97109      12-31-2020               RIVER VALLEY    OH  $393,016,300
# 97110      12-31-2020             ROCKY MOUNTAIN    MT  $316,032,867
# 97111      12-31-2020                      ABBEY    OH  $112,006,788
#
#           Current_mbrs                  Classification  Net_worth_ratio  \
# CU_Number
# ...

# %%
# write df to excel
with pd.ExcelWriter('MSUFCU.xlsx', mode='a', engine='openpyxl') as writer:
    Y2020_df.to_excel(writer, sheet_name='2020')
